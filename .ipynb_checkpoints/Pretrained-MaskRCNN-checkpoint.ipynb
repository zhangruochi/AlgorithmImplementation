# %% [markdown]
# ## MaskRCNN for Object Detection Finetuning

# %%
import os
import numpy as np
import torch
from PIL import Image
from torch.utils.data import Dataset
from pathlib import Path
import os
from matplotlib import pyplot as plt
import matplotlib.patches as patches

# %%
import sys
sys.path.append("/Users/ZRC")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
root = Path("./data/PennFudanPed")
images = root/"PNGImages"
masks =  root/"PedMasks"

# %%
assert len(list(images.glob("*.png"))) == len(list(masks.glob("*.png")))

# %%
image_sample = np.array(Image.open(images/"FudanPed00001.png"))
mask_sample = np.array(Image.open(masks/"FudanPed00001_mask.png"))

# %%
plt.imshow(image_sample)

# %%
plt.imshow(mask_sample)

# %%
mask_sample.shape, image_sample.shape
# Out:
# ((536, 559), (536, 559, 3))

# %%
obj_ids = np.unique(mask_sample)[1:]

# %%
obj_ids
# Out:
# array([1, 2], dtype=uint8)

# %%
pos_0 = np.where(mask_sample == obj_ids[0])
x_min_0 = np.min(pos_0[1])
x_max_0 = np.max(pos_0[1])
y_min_0 = np.min(pos_0[0])
y_max_0 = np.max(pos_0[0])

# %%
pos_1 = np.where(mask_sample == obj_ids[1])
x_min_1 = np.min(pos_1[1])
x_max_1 = np.max(pos_1[1])
y_min_1 = np.min(pos_1[0])
y_max_1 = np.max(pos_1[0])

# %%
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(mask_sample)

# Create a Rectangle patch
rect_0 = patches.Rectangle((x_min_0,y_min_0),x_max_0 - x_min_0,y_max_0 - y_min_0,linewidth=1,edgecolor='r',facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect_0)

rect_1 = patches.Rectangle((x_min_1,y_min_1),x_max_1 - x_min_1, y_max_1 - y_min,linewidth=1,edgecolor='r',facecolor='none')
ax.add_patch(rect_1)


plt.show()

# %%
from coke.visualization.image import show_object_box
show_object_box(image_sample, mask_sample)

# %%
class PennFudanDataset(object):
    def __init__(self, root, transforms):
        self.root = root
        self.transforms = transforms
        # load all image files, sorting them to
        # ensure that they are aligned
        self.imgs = list(sorted(os.listdir(os.path.join(root, "PNGImages"))))
        self.masks = list(sorted(os.listdir(os.path.join(root, "PedMasks"))))
        
        assert len(self.imgs) == len(self.masks)    
        
    def __getitem__(self ,idx):
        img_path = os.path.join(self.root, "PNGImages", self.imgs[idx])
        mask_path = os.path.join(self.root, "PedMasks", self.masks[idx])
        img = Image.open(img_path).convert("RGB")    
        mask = np.array(Image.open(mask_path))
        
        obj_ids = np.unique(mask)[1:]
        num_objs = len(obj_ids)
        boxes = []
        
        for i in range(num_objs):
            pos = np.where(mask == obj_ids[i])
            xmin = np.min(pos[1])
            xmax = np.max(pos[1])
            ymin = np.min(pos[0])
            ymax = np.max(pos[0])
            boxes.append([xmin, ymin, xmax, ymax])
        
        # convert everything into a torch.Tensor
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        
        # there is only one class
        labels = torch.ones((num_objs,), dtype=torch.int64)
        
        masks = torch.as_tensor(masks, dtype=torch.uint8)
        
        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        
        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)
        
        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["masks"] = masks
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd
        
        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target
    
    def __len__(self):
        return len(self.imgs)
